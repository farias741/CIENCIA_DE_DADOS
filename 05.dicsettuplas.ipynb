# %% [markdown]
# # Formação Cientista de Dados
# ## Prática no Python
# ### Dicionários, Sets e tuplas

# %%
#dicionários: estrutura chave/valor
#a estrutura chave e valor é uma estrutura muito comum em ciência de dados
#existe banco de dados, por exemplo, que são especializados em armazenar esse tipo de informação,
#é uma informação bastante simples, temos apenas uma chave e um valor, a questão que a chave e o valor
#eles estão sempre relacionados, e normalmente utilizamos a chave com identificador da informação(valor)
Notas = {'João': 6.0, 'Maria': 8.0, 'Pedro': 6.5}
print(Notas)
# Out:
# {'João': 6.0, 'Maria': 8.0, 'Pedro': 6.5}

# %%
print(Notas['João'])
# Out:
# 6.0

# %%
#Todas as chaves
Notas.keys()
# Out:
# dict_keys(['João', 'Maria', 'Pedro'])

# %%
#todos os valores
Notas.values()
# Out:
# dict_values([6.0, 8.0, 6.5])

# %%
#Testa logicamente a existência
print('João' in Notas)
print('Fernando' in Notas)
# Out:
# True
# False

# %%
#apaga um elemento
del Notas['João']
print(Notas)
# Out:
# {'Maria': 8.0, 'Pedro': 6.5}

# %%
#inclui um elemento
Notas['Ana'] = 9
print(Notas)
# Out:
# {'Maria': 8.0, 'Pedro': 6.5, 'Ana': 9}

# %%
#busca um valor, se não encontrar mostra segundo parametro
Notas.get('Geraldo',"Não encontrado!")
# Out:
# 'Não encontrado!'

# %%
#sets são conjuntos não ordenados de elementos não repetidos
bigdata = {'Spark', 'Hive', "Sqoop"}
print(bigdata)
# Out:
# {'Spark', 'Sqoop', 'Hive'}

# %%
#verifica existência
print('Spark' in bigdata)
# Out:
# True

# %%
#adiciona elemento
bigdata.add('Hadoop')
bigdata
# Out:
# {'Hadoop', 'Hive', 'Spark', 'Sqoop'}

# %%
#número de elementos
print(len(bigdata))
# Out:
# 4

# %%
bigdata.add("Spark")
bigdata
# Out:
# {'Hadoop', 'Hive', 'Spark', 'Sqoop'}

# %%
#tuplas são listas que não podem ser alteradas
#listas usam [], tuplas usam ()
tupla = (1,2,3,4,5,6,7)
tupla
# Out:
# (1, 2, 3, 4, 5, 6, 7)

# %%
tupla[4]
# Out:
# 5

# %%
#dicionários em que cada posição recebe uma tupla
dic2 = {(0, 1): 0, (1, 2): 1, (2, 3): 2, (3, 4): 3, (4, 5): 4,(5, 6): 5, (6, 7): 6, (7, 8): 7, (8, 9): 8, (9, 10): 9}
dic2
# Out:
# {(0, 1): 0,
#  (1, 2): 1,
#  (2, 3): 2,
#  (3, 4): 3,
#  (4, 5): 4,
#  (5, 6): 5,
#  (6, 7): 6,
#  (7, 8): 7,
#  (8, 9): 8,
#  (9, 10): 9}

# %%
print(type(Notas))
print(type(bigdata))
print(type(tupla))
# Out:
# <class 'dict'>
# <class 'set'>
# <class 'tuple'>
